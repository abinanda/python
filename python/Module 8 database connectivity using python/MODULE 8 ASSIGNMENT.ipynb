# %% [markdown]
# ### 1)	Connect to MySQL using Python, and push "Data.csv" into the database.

# %%
from sqlalchemy import create_engine
engine=create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}".format(user="root",pw="Maxima1!",db="mysql"))

# %%
import pandas as pd
df=pd.read_csv(r"H:\studies\360digitMG\assignment problem statement\python\Module 8 database connectivity using python\Data.csv")
df.to_sql("data1",con=engine,if_exists='replace',index=False)
# Out:
# 310

# %% [markdown]
# ### 2)	Connect to MySQL using Python, push "Indian Cities.csv" into the database, and then use Python to load the data from MySQL.

# %%
from sqlalchemy import create_engine
engine=create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}".format(user="root",pw="Maxima1!",db="mysql"))

df1=pd.read_csv(r"H:\studies\360digitMG\assignment problem statement\python\Module 8 database connectivity using python\Indian_cities.csv")

# %%
df1.to_sql("data1",con=engine,if_exists="replace",index=True)
# Out:
# 493

# %%
sql_query="select * from data1"
data1=pd.read_sql_query(sql_query,engine)

# %%
data1
# Out:
#      index   name_of_city  state_code      state_name  dist_code  \
# 0        0        Abohar            3          PUNJAB          9
# 1        1      Achalpur           27     MAHARASHTRA          7
# 2        2      Adilabad           28  ANDHRA PRADESH          1
# 3        3     Adityapur           20       JHARKHAND         24
# 4        4         Adoni           28  ANDHRA PRADESH         21
# ..     ...            ...         ...             ...        ...
# 488    488  Vizianagaram           28  ANDHRA PRADESH         12
# 489    489      Warangal           28  ANDHRA PRADESH          9
# 490    490        Wardha           27     MAHARASHTRA          8
# 491    491   Yamunanagar            6         HARYANA          3
# 492    492      Yavatmal           27     MAHARASHTRA         14
#
#      population_total  population_male  population_female  \
# 0              145238            76840              68398
# 1              112293            58256              54037
# ...
